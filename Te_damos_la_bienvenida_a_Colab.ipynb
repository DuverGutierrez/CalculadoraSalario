# %% [markdown]
# <a href="https://colab.research.google.com/github/DuverGutierrez/CalculadoraSalario/blob/main/Te_damos_la_bienvenida_a_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mi primer codigo Python

# %%
print("Bienvenido, hola mundo");
# Out:
# Bienvenido, hola mundo

# %%
#introduccion a variables
goles_mundial_2022 = 250
goles_mundial_2026 = 400
print(goles_mundial_2022)
print(goles_mundial_2026)
# Out:
# 250
# 400
